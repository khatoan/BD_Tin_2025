# %%
print("Hello")
# Out:
# Hello

# %%
#Bài toán trả tiền (61/sgk)
def backtrack(i):
    for v in range(2):
        x.append(v)
        if i == n -1:
            updateSolution()
        else:
            backtrack(i+1)
        x.pop()
def updateSolution():
    global c
    sumT = 0
    for k in range(n):
        if x[k]==1:
            sumT += T[k]
    if sumT == S:
        print(list(x))
        c += 1
S = 130
T = [10, 20, 50, 50, 100]
n = len(T)
x = []
c = 0
backtrack(0)
print("Tổng số phương án:", c)
# Out:
# [1, 1, 0, 0, 1]
# [1, 1, 1, 1, 0]
# Tổng số phương án: 2

# %%
# Rút tiền từ máy ATM
# Viết chương trình nhập vào số tiền S. Hãy giúp máy trả tiền cho khách hàng sao cho số lượng các tờ tiền để trả là ít nhất
def backtrack(i):
    for v in range(2):
        x.append(v)
        if i == n -1:
            updateSolution()
        else:
            backtrack(i+1)
        x.pop()

def updateSolution():
    global best, ans
    so_to = 0
    sumT = 0
    for k in range(n):
        if x[k]==1:
            sumT += T[k]
    if sumT == S:
        for k in range(n):
            if x[k] == 1:
                so_to += 1
        if so_to < best:
            best = so_to
            ans = list(x)
S = 1000
T = [200, 200, 100, 500, 50, 200, 200, 50]
T = sorted(T)
ans = []
print("Dãy T sau sắp xếp:", T)
best = float('inf')
n = len(T)
x = []
backtrack(0)
print("Cách chọn tối ưu:", ans)
# Out:
# Dãy T sau sắp xếp: [50, 50, 100, 200, 200, 200, 200, 500]
# Cách chọn tối ưu: [0, 0, 1, 0, 0, 1, 1, 1]

# %%
# Hoán vị các chữ cái
def backtrack(i):
    for v in S:
        if not(v in x):
            x.append(v)
            if i == n-1:
                updateSolution()
            else: 
                backtrack(i+1)
            x.pop()
def updateSolution():
    for k in x:
        print(k, end = "")
    print()
S = list(input("Nhập S"))
x = []
n = len(S)
backtrack(0)
# Out:
# TIN
# TNI
# ITN
# INT
# NTI
# NIT
