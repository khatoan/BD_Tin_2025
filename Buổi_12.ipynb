# %%
print("Hello")
# Out:
# Hello

# %%
def backtrack(i):
    for v in sign:
        x.append(v)
        if i == k- 1:
            KQ.append(list(x))
        else:
            backtrack(i + 1)
        x.pop()

A = [i**2 for i in range(1, 21)]
x = []
n = 0
sign = [1, -1]
OK = False
for k in range(1, 21):
    KQ = []
    backtrack(0)
    for B in KQ:
        T = 0
        for j in range(k):
            T = T + B[j] * A[j]
        if T == n:
            print(B)
            OK = True
            break
    if OK:
        break

for u in range(len(B)):
    if B[u] == 1:
        d = "x"
    else: 
        d = "-"
    s = s + d + str(A[u]) + " "
# Out:
# [1, 1, -1, 1, -1, -1, 1]
# +1 +4 -9 +16 -25 -36 +49
